# %%
import os
import pandas as pd
import numpy as np

os.chdir("C:/Users/Administrator/Desktop")
mydata=pd.read_csv("data.csv",sep=",",encoding="utf-8")

# %%
mydata.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
mydata.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
#提取单行的两种等价方式
mydata.model

mydata["model"]
# Out:
# 0                      a4
# 1                      a4
# 2                      a4
# 3                      a4
# 4                      a4
# 5                      a4
# 6                      a4
# 7              a4 quattro
# 8              a4 quattro
# 9              a4 quattro
# 10             a4 quattro
# 11             a4 quattro
# 12             a4 quattro
# 13             a4 quattro
# 14             a4 quattro
# 15             a6 quattro
# 16             a6 quattro
# 17             a6 quattro
# 18     c1500 suburban 2wd
# 19     c1500 suburban 2wd
# 20     c1500 suburban 2wd
# 21     c1500 suburban 2wd
# 22     c1500 suburban 2wd
# 23               corvette
# 24               corvette
# 25               corvette
# 26               corvette
# 27               corvette
# 28        k1500 tahoe 4wd
# 29        k1500 tahoe 4wd
#               ...
# 204     toyota tacoma 4wd
# 205     toyota tacoma 4wd
# 206     toyota tacoma 4wd
# 207                   gti
# 208                   gti
# ...

# %%
mydata[["model","manufacturer"]]
# Out:
#                   model manufacturer
# 0                    a4         audi
# 1                    a4         audi
# 2                    a4         audi
# 3                    a4         audi
# 4                    a4         audi
# 5                    a4         audi
# 6                    a4         audi
# 7            a4 quattro         audi
# 8            a4 quattro         audi
# 9            a4 quattro         audi
# 10           a4 quattro         audi
# 11           a4 quattro         audi
# 12           a4 quattro         audi
# 13           a4 quattro         audi
# 14           a4 quattro         audi
# 15           a6 quattro         audi
# 16           a6 quattro         audi
# 17           a6 quattro         audi
# 18   c1500 suburban 2wd    chevrolet
# 19   c1500 suburban 2wd    chevrolet
# 20   c1500 suburban 2wd    chevrolet
# 21   c1500 suburban 2wd    chevrolet
# 22   c1500 suburban 2wd    chevrolet
# 23             corvette    chevrolet
# ...

# %%
#通过指定序号范围来提取行：
mydata[1:10]
#默认情况下序列范围是针对行索引，字符串默认是针对列索引

mydata[200:]#切出201个之后的所有记录，从0开始编号

mydata[:100]#切出前100个的所有记录，不包括尾部

mydata[:]#提取所有记录

mydata[::2]#间隔几个单位取一次值
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 0           audi                      a4    1.8  1999    4    auto(l5)   f
# 2           audi                      a4    2.0  2008    4  manual(m6)   f
# 4           audi                      a4    2.8  1999    6    auto(l5)   f
# 6           audi                      a4    3.1  2008    6    auto(av)   f
# 8           audi              a4 quattro    1.8  1999    4    auto(l5)   4
# 10          audi              a4 quattro    2.0  2008    4    auto(s6)   4
# 12          audi              a4 quattro    2.8  1999    6  manual(m5)   4
# 14          audi              a4 quattro    3.1  2008    6  manual(m6)   4
# 16          audi              a6 quattro    3.1  2008    6    auto(s6)   4
# 18     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# 20     chevrolet      c1500 suburban 2wd    5.3  2008    8    auto(l4)   r
# ...

# %%
#同时叠加行列索引与切片
mydata[1:10][["model","manufacturer"]]
# Out:
#         model manufacturer
# 1          a4         audi
# 2          a4         audi
# 3          a4         audi
# 4          a4         audi
# 5          a4         audi
# 6          a4         audi
# 7  a4 quattro         audi
# 8  a4 quattro         audi
# 9  a4 quattro         audi

# %%
mydata[["model","manufacturer"]][1:10]
# Out:
#         model manufacturer
# 1          a4         audi
# 2          a4         audi
# 3          a4         audi
# 4          a4         audi
# 5          a4         audi
# 6          a4         audi
# 7  a4 quattro         audi
# 8  a4 quattro         audi
# 9  a4 quattro         audi

# %%
#标签索引：针对数据框的索引字段

mydata.loc[3]#按索引提取单行的数值，以列形式呈现

mydata.loc[0:5]#按索引提取区域行数值

mydata.loc[1:10,["model","manufacturer"]]#行列同时索引
# Out:
#          model manufacturer
# 1           a4         audi
# 2           a4         audi
# 3           a4         audi
# 4           a4         audi
# 5           a4         audi
# 6           a4         audi
# 7   a4 quattro         audi
# 8   a4 quattro         audi
# 9   a4 quattro         audi
# 10  a4 quattro         audi

# %%
# 位置索引：只针对行列位置对应的序号
#iloc索引，列位置可以忽略，行位置必须要占位

mydata.iloc[[0,2]] #等价于mydata.iloc[[0,2],:]

mydata.iloc[1:] #等价于mydata.iloc[1:,:]

mydata.iloc[1,[0,1]]

mydata.iloc[:3,2]

mydata.iloc[[0,2,5],[4,5]]
# Out:
#    cyl       trans
# 0    4    auto(l5)
# 2    4  manual(m6)
# 5    6  manual(m5)

# %%
#条件索引
mydata[(mydata["model"]=="audi") | (mydata["manufacturer"]=="mercury")][["model","manufacturer","year","class"]]
# Out:
#                model manufacturer  year class
# 137  mountaineer 4wd      mercury  1999   suv
# 138  mountaineer 4wd      mercury  2008   suv
# 139  mountaineer 4wd      mercury  2008   suv
# 140  mountaineer 4wd      mercury  1999   suv

# %%
#这种基于数据框本身的条件索引用法不够优雅，需要额外写很多字段名称，借助外部函数:
mydata.query('model=="audi" | manufacturer=="mercury"')

#列名不需要引号，query整体用单引号
# Out:
#     manufacturer            model  displ  year  cyl     trans drv  cty  hwy  \
# 137      mercury  mountaineer 4wd    4.0  1999    6  auto(l5)   4   14   17
# 138      mercury  mountaineer 4wd    4.0  2008    6  auto(l5)   4   13   19
# 139      mercury  mountaineer 4wd    4.6  2008    8  auto(l6)   4   13   19
# 140      mercury  mountaineer 4wd    5.0  1999    8  auto(l4)   4   13   17
#
#     fl class
# 137  r   suv
# 138  r   suv
# 139  r   suv
# 140  r   suv

# %% [markdown]
# #### R语言和Python的切片索引规则重要的区别：
# - R语言中生成数据框使用圆括号，Python中则根据不同数据类型分别定义（列表用方括号、元组用圆括号、字典和几何用花括号）
# - R语言和Python索引都用方括号，且都是使用逗号进行行规则和列规则的位置间隔
# - R语言与Python在索引多行多列时传入数据类型不同，R语言传入向量，Python传入列表
# - 在索引多行时，R与Python都可以使用连续行列，均需提供占位符号，R语言留白即可标识全选，Python占位则必须提供：符号；在索引多列时，均无需提供占位符号
# - R语言与Python都接受逻辑表达式：|或，&且
# - R语言索引从1开始，Python从0开始（不包括尾部）
# - P语言与Python均可以基于数据框自身进行索引切片，同时又可以通过外部索引函数进行条件索引
