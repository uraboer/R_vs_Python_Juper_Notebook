# %%
#数据框索引
#基于数据框本身提取
#subset函数
#filter+select函数

# %%
library(ggplot2)

# %%
# data()
head(mpg)
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %%
summary(mpg)
# Out:
#  manufacturer          model               displ            year
#  Length:234         Length:234         Min.   :1.600   Min.   :1999
#  Class :character   Class :character   1st Qu.:2.400   1st Qu.:1999
#  Mode  :character   Mode  :character   Median :3.300   Median :2004
#                                        Mean   :3.472   Mean   :2004
#                                        3rd Qu.:4.600   3rd Qu.:2008
#                                        Max.   :7.000   Max.   :2008
#       cyl           trans               drv                 cty
#  Min.   :4.000   Length:234         Length:234         Min.   : 9.00
#  1st Qu.:4.000   Class :character   Class :character   1st Qu.:14.00
#  Median :6.000   Mode  :character   Mode  :character   Median :17.00
#  Mean   :5.889                                         Mean   :16.86
#  3rd Qu.:8.000                                         3rd Qu.:19.00
#  Max.   :8.000                                         Max.   :35.00
# ...

# %%
mpg[,c(2,3)]
# Out:
#     model              displ
# 1   a4                 1.8
# 2   a4                 1.8
# 3   a4                 2.0
# 4   a4                 2.0
# 5   a4                 2.8
# 6   a4                 2.8
# 7   a4                 3.1
# 8   a4 quattro         1.8
# 9   a4 quattro         1.8
# 10  a4 quattro         2.0
# 11  a4 quattro         2.0
# 12  a4 quattro         2.8
# 13  a4 quattro         2.8
# 14  a4 quattro         3.1
# 15  a4 quattro         3.1
# 16  a6 quattro         2.8
# 17  a6 quattro         3.1
# 18  a6 quattro         4.2
# 19  c1500 suburban 2wd 5.3
# 20  c1500 suburban 2wd 5.3
# 21  c1500 suburban 2wd 5.3
# 22  c1500 suburban 2wd 5.7
# 23  c1500 suburban 2wd 6.0
# 24  corvette           5.7
# 25  corvette           5.7
# 26  corvette           6.2
# 27  corvette           6.2
# 28  corvette           7.0
# 29  k1500 tahoe 4wd    5.3
# 30  k1500 tahoe 4wd    5.3
# ... ...                ...
# 205 toyota tacoma 4wd  3.4
# 206 toyota tacoma 4wd  4.0
# ...

# %%
mpg[,c("model","displ")]
# Out:
#     model              displ
# 1   a4                 1.8
# 2   a4                 1.8
# 3   a4                 2.0
# 4   a4                 2.0
# 5   a4                 2.8
# 6   a4                 2.8
# 7   a4                 3.1
# 8   a4 quattro         1.8
# 9   a4 quattro         1.8
# 10  a4 quattro         2.0
# 11  a4 quattro         2.0
# 12  a4 quattro         2.8
# 13  a4 quattro         2.8
# 14  a4 quattro         3.1
# 15  a4 quattro         3.1
# 16  a6 quattro         2.8
# 17  a6 quattro         3.1
# 18  a6 quattro         4.2
# 19  c1500 suburban 2wd 5.3
# 20  c1500 suburban 2wd 5.3
# 21  c1500 suburban 2wd 5.3
# 22  c1500 suburban 2wd 5.7
# 23  c1500 suburban 2wd 6.0
# 24  corvette           5.7
# 25  corvette           5.7
# 26  corvette           6.2
# 27  corvette           6.2
# 28  corvette           7.0
# 29  k1500 tahoe 4wd    5.3
# 30  k1500 tahoe 4wd    5.3
# ... ...                ...
# 205 toyota tacoma 4wd  3.4
# 206 toyota tacoma 4wd  4.0
# ...

# %%
mpg$model 

#等价于mpg[,"model"]，但会自动降维
# Out:
#   [1] "a4"                     "a4"                     "a4"
#   [4] "a4"                     "a4"                     "a4"
#   [7] "a4"                     "a4 quattro"             "a4 quattro"
#  [10] "a4 quattro"             "a4 quattro"             "a4 quattro"
#  [13] "a4 quattro"             "a4 quattro"             "a4 quattro"
#  [16] "a6 quattro"             "a6 quattro"             "a6 quattro"
#  [19] "c1500 suburban 2wd"     "c1500 suburban 2wd"     "c1500 suburban 2wd"
#  [22] "c1500 suburban 2wd"     "c1500 suburban 2wd"     "corvette"
#  [25] "corvette"               "corvette"               "corvette"
#  [28] "corvette"               "k1500 tahoe 4wd"        "k1500 tahoe 4wd"
#  [31] "k1500 tahoe 4wd"        "k1500 tahoe 4wd"        "malibu"
#  [34] "malibu"                 "malibu"                 "malibu"
#  [37] "malibu"                 "caravan 2wd"            "caravan 2wd"
#  [40] "caravan 2wd"            "caravan 2wd"            "caravan 2wd"
# ...

# %%
#行切片
mpg[1:10,]
# Out:
#    manufacturer model      displ year cyl trans      drv cty hwy fl class
# 1  audi         a4         1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2  audi         a4         1.8   1999 4   manual(m5) f   21  29  p  compact
# 3  audi         a4         2.0   2008 4   manual(m6) f   20  31  p  compact
# 4  audi         a4         2.0   2008 4   auto(av)   f   21  30  p  compact
# 5  audi         a4         2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6  audi         a4         2.8   1999 6   manual(m5) f   18  26  p  compact
# 7  audi         a4         3.1   2008 6   auto(av)   f   18  27  p  compact
# 8  audi         a4 quattro 1.8   1999 4   manual(m5) 4   18  26  p  compact
# 9  audi         a4 quattro 1.8   1999 4   auto(l5)   4   16  25  p  compact
# 10 audi         a4 quattro 2.0   2008 4   manual(m6) 4   20  28  p  compact

# %%
mpg[mpg$model=="audi" | mpg$manufacturer=="mercury",]

mpg[mpg$model=="a4" & mpg$manufacturer=="audi",]
# Out:
#   manufacturer model           displ year cyl trans    drv cty hwy fl class
# 1 mercury      mountaineer 4wd 4.0   1999 6   auto(l5) 4   14  17  r  suv
# 2 mercury      mountaineer 4wd 4.0   2008 6   auto(l5) 4   13  19  r  suv
# 3 mercury      mountaineer 4wd 4.6   2008 8   auto(l6) 4   13  19  r  suv
# 4 mercury      mountaineer 4wd 5.0   1999 8   auto(l4) 4   13  17  r  suv
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact
# 7 audi         a4    3.1   2008 6   auto(av)   f   18  27  p  compact

# %%
#以上索引是在没有借助任何外部函数的基础上，通过数据框自身的规则完成的，很不优雅，
#因为写了很多重复的名称，mpg$...
#一种更优雅的方式是使用subset函数进行行列筛选

subset(mpg,model=="audi" | manufacturer=="mercury",select=c("model","manufacturer","year"))

subset(mpg,model=="a4" & manufacturer=="audi",select=c("model","manufacturer","year"))
# Out:
#   model           manufacturer year
# 1 mountaineer 4wd mercury      1999
# 2 mountaineer 4wd mercury      2008
# 3 mountaineer 4wd mercury      2008
# 4 mountaineer 4wd mercury      1999
#   model manufacturer year
# 1 a4    audi         1999
# 2 a4    audi         1999
# 3 a4    audi         2008
# 4 a4    audi         2008
# 5 a4    audi         1999
# 6 a4    audi         1999
# 7 a4    audi         2008

# %%
#还有一种更加高级优雅的方式是使用dplyr包中的select和filter函数进行行列索引与切片

library(dplyr)

mpg %>% filter(model=="audi" | manufacturer=="mercury") %>% select(model,manufacturer,year)

mpg %>% filter(model=="a4" | manufacturer=="audi") %>% select(model,manufacturer,year)
# Out:
#   model           manufacturer year
# 1 mountaineer 4wd mercury      1999
# 2 mountaineer 4wd mercury      2008
# 3 mountaineer 4wd mercury      2008
# 4 mountaineer 4wd mercury      1999
#    model      manufacturer year
# 1  a4         audi         1999
# 2  a4         audi         1999
# 3  a4         audi         2008
# 4  a4         audi         2008
# 5  a4         audi         1999
# 6  a4         audi         1999
# 7  a4         audi         2008
# 8  a4 quattro audi         1999
# 9  a4 quattro audi         1999
# 10 a4 quattro audi         2008
# 11 a4 quattro audi         2008
# 12 a4 quattro audi         1999
# 13 a4 quattro audi         1999
# 14 a4 quattro audi         2008
# 15 a4 quattro audi         2008
# 16 a6 quattro audi         1999
# 17 a6 quattro audi         2008
# 18 a6 quattro audi         2008
